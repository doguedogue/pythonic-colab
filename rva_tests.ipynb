# %% [markdown]
# <a href="https://colab.research.google.com/github/doguedogue/pythonic-colab/blob/main/rva_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pythonic - Colab

# %% [markdown]
# ## Aula 1

# %% [markdown]
# ### Carga google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importa archivo en drive, lo convierte en frame pandas, lee los primeros registros del archivo

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/inmuebles_bogota.csv')

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %% [markdown]
# ### Conteo de filas y columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# ### Lista las columnas del archivo

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# ### Reemplaza nombres de columnas con carácteres especiales y muestra 10 registros random

# %%
columnas = {'Baños': 'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 20    Apartamento      Apartamento en venta en Usaquén             1      2
# 8138         Casa                Casa en venta en Suba             3      2
# 1104  Apartamento      Apartamento en venta en Boyaca              2      2
# 9300  Apartamento    Apartamento en venta en Chapinero             3      3
# 5013  Apartamento         Apartamento en venta en Suba             3      3
# 2432  Apartamento      Apartamento en venta en Kennedy             3      2
# 4751         Casa                Casa en venta en Suba             3      3
# 9144         Casa             Casa en venta en Kennedy             3      3
# 7148  Apartamento     Apartamento en venta en Fontibón             3      2
# 7241  Apartamento  Apartamento en venta en Teusaquillo             2      2
#
#       Area       Barrio                                 UPZ            Valor
# 20      50      Usaquén                             Usaquén    $ 420.000.000
# 8138   105         Suba                                Suba    $ 320.000.000
# 1104    52      Boyaca                          Boyacá Real    $ 230.000.000
# 9300   287    Chapinero  CHAPINERO: Pardo Rubio + Chapinero  $ 1.950.000.000
# 5013   121         Suba                                Suba    $ 850.000.000
# 2432    81      Kennedy                     Kennedy Central    $ 360.000.000
# 4751    83         Suba                                Suba    $ 325.000.000
# 9144   120      Kennedy                     Kennedy Central    $ 360.000.000
# 7148   109     Fontibón                            Fontibón    $ 490.000.000
# 7241    57  Teusaquillo                         Teusaquillo    $ 306.000.000

# %% [markdown]
# ### Información del archivo ahora frame pandas cargado

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ### Busca y muestra un registro en especial (300)

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# ### Busca y muestra un rango de registros (300 al 304)

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# ### Obtiene el valor de una celda en especifico

# %%
inmuebles['Valor'][301]
# Out:
# '$ 980.000.000'

# %% [markdown]
# ### Obtiene el valor de un rango de celdas en especifico

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# ### Ver el tipo de información revisada

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Obtener promedio por columna: Área

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# ### Serie que cumpla una codición

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# ### Conteo de los que cumplan la condición

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %% [markdown]
# ### Asignación a variable de cierta condición

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
inmuebles_chico
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# ### Creación de Sub-Frame de inmuebles con cierta condición

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %% [markdown]
# ### Obtener promedio por columna: Área de Barrio específico

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %% [markdown]
# ### Conteo de Barrios

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# ### Nombre de Barrios

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# ### Gráfica de todos los barrios

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Gráfica de los top 10 barrios

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# ### Desafío
#
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
#
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimos y máximos

# %% [markdown]
# ### 1

# %%
inmuebles.groupby(['Barrio'])['Area'].mean().nlargest(10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
inmuebles.groupby(['Barrio'])['Area'].mean().nlargest(10).plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# ### 2

# %%
media = inmuebles['Area'].mean()
mediana = inmuebles['Area'].median()
moda = inmuebles['Area'].mode()
minimo = inmuebles['Area'].min()
maximo = inmuebles['Area'].max()
print("""
    Media: %.2f
    Mediana: %.2f
    Moda: %.2f
    Mínimo: %.2f
    Máximo: %.2f
""" % (media, mediana, moda, minimo, maximo))
# Out:
#     Media: 146.66
#     Mediana: 80.00
#     Moda: 47.00
#     Mínimo: 2.00
#     Máximo: 166243.00

# %%
inmuebles.groupby(['Barrio'])['Barrio'].count().nlargest(10)
# Out:
# Barrio
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
# Barrios Unidos         473
# Engativa               462
# Suba                   443
# Santa Barbara          438
# Chapinero              332
# Name: Barrio, dtype: int64

# %% [markdown]
# ## Aula 2

# %% [markdown]
# ### Revisa información muestra

# %%
inmuebles.sample(5)
# Out:
#              Tipo                          Descripcion  Habitaciones  Banos  \
# 1566         Casa             Casa en venta en Kennedy             2      1
# 592   Apartamento      Apartamento en venta en Usaquén             3      3
# 5022         Casa  Casa en venta en Zona Noroccidental             4      6
# 5543         Casa  Casa en venta en Rafael Uribe Uribe             9      4
# 1508  Apartamento     Apartamento en venta en Fontibón             3      2
#
#       Area              Barrio                                 UPZ  \
# 1566    43             Kennedy                     Kennedy Central
# 592    107             Usaquén                             Usaquén
# 5022   583  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 5543   250  Rafael Uribe Uribe                       Los Alcázares
# 1508    83            Fontibón                            Fontibón
#
#                 Valor
# 1566    $ 116.000.000
# 592     $ 660.000.000
# 5022  $ 2.650.000.000
# 5543    $ 460.000.000
# 1508    $ 390.000.000

# %% [markdown]
# ### Tipo de datos en cada columna

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ### Valor en el campo: Valor

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %% [markdown]
# ### Muestra el tipo de dato de Valor

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# ### Como es string se trata como cadena y se quita el signo de $

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# ### Separar toda la columna Valor (Devuelve un Data series)

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %% [markdown]
# ### Separar toda la columna Valor (Devuelve una Data Frame)

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# ### Asignar el data frame a una variable

# %%
valor = inmuebles.Valor.str.split(expand=True)

# %% [markdown]
# ### Crear dos nuevas columnas al frame inmuebles y agregarle las columnas separadas

# %%
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 219   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1296  Apartamento            Apartamento en venta en Cedritos             2
# 6438         Casa                    Casa en venta en Usaquén             4
# 8905         Casa              Casa en venta en Santa Barbara            10
# 5023  Apartamento         Apartamento en venta en Los Rosales             3
#
#       Banos  Area              Barrio                                    UPZ  \
# 219       4   300  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1296      3    76            Cedritos                                Usaquén
# 6438      4   124             Usaquén                                Usaquén
# 8905      4   348       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 5023      3   145         Los Rosales     CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor Moneda         Precio
# 219   $ 1.560.000.000      $  1.560.000.000
# 1296    $ 450.000.000      $    450.000.000
# 6438    $ 700.000.000      $    700.000.000
# 8905  $ 1.550.000.000      $  1.550.000.000
# 5023  $ 1.100.000.000      $  1.100.000.000

# %% [markdown]
# ### Revisando los tipos del data frame

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# ### Sumando la columna Precio que es objeto(str) concatena la info

# %%
inmuebles['Precio'].sample(5).sum()
# Out:
# '4.000.000.000466.000.000490.000.000475.000.000350.000.000'

# %% [markdown]
# ### Remplazando el carácter punto (.) en el precio

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex=True)

# %% [markdown]
# ### Mostrando un sub-data frame al pasar una lista de las columnas

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# ### Transformar el tipo de dato a númerico y quitarle 6 ceros

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# ### Imprimiendo 5 registros random

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 5087  Apartamento       Apartamento en venta en Pinar De Suba             3
# 8822  Apartamento  Apartamento en venta en Zona Noroccidental             1
# 4656  Apartamento   Apartamento en venta en Chapinero Central             1
# 4742  Apartamento            Apartamento en venta en Cedritos             2
# 8321  Apartamento      Apartamento en venta en Barrios Unidos             3
#
#       Banos  Area              Barrio                                 UPZ  \
# 5087      2    77       Pinar De Suba                                Suba
# 8822      1    26  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4656      2    43   Chapinero Central           Localidad Chapinero resto
# 4742      1    61            Cedritos                             Usaquén
# 8321      3   120      Barrios Unidos                           Los Andes
#
#               Valor Moneda     Precio  Precio_Millon
# 5087  $ 278.000.000      $  278000000          278.0
# 8822  $ 210.000.000      $  210000000          210.0
# 4656  $ 280.500.000      $  280500000          280.5
# 4742  $ 252.000.000      $  252000000          252.0
# 8321  $ 640.000.000      $  640000000          640.0

# %% [markdown]
# ### Describir el data frame

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# ### Modificando la precisión del float y número de decimales

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# ### Localizando un registro con una información en especifico (110 hab.)

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# ### Gráfico de un histograma
# - Gráfica de barras vs histograma
# - Gráfica de barras = repetición de una variable
# - Gráfica de un histograma = Frecuencia de una variable
# - Nos ayuda a entender la distribución de frecuencias de una variable en este caso el precio
# - Los bins la separación de cada uno de los rangos bloques que se visualizan en el eje horizontal

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Bibliotecas para visualización de información ademas de pandas, estan:
# - matplotlib (pyplot)
# - seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles,x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title ('Distribución de los precios de los inmuebles en Bogotá')
plt.xlim(50, 1000)
#plt.ylim(0, 100)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/distribucion_inmuebles.png', format='png')
plt.show()

# %% [markdown]
# ### Desafíos
# 1. Estudiar mejor el histograma de valores, seleccionar tres tipos de inmuebles (refinar el gráfico: títulos, aumentar el tamaño de labels, colores, conclusión de la información.
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.
